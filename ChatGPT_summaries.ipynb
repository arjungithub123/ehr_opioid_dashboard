# %%
# !pip install openai

# %%
import openai
def generate_patient_summary(prompt):
    openai.api_key = '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'
    response = openai.Completion.create(
        model = "gpt-4-1106-preview",
        engine="text-davinci-002",  
        prompt=prompt,
        n = 1, 
        stop=None, 
        temperature=0.0001
    )
    summary = response.choices[0].text
    return summary

# output = generate_patient_summary(prompt)
# print(output)

# %%
import pandas as pd
demographics_csv = pd.read_csv('/Users/arjun_ob/Downloads/Opioid_Dashboard_Handover/demographics_all1.csv')
diagnosis_csv = pd.read_csv('/Users/arjun_ob/Downloads/Opioid_Dashboard_Handover/diagnosis_final.csv')
medication_csv = pd.read_csv('/Users/arjun_ob/Downloads/Opioid_Dashboard_Handover/medication_final.csv')

# %%
diagnosis_csv
# Out:
#       Unnamed: 0  patient id  \
# 0              0   112459790
# 1              1   112459790
# 2              2   181403665
# 3              3   181403665
# 4              4   151388186
# ...          ...         ...
# 7233        7233   180358124
# 7234        7234   192956301
# 7235        7235   192956301
# 7236        7236   192956301
# 7237        7237   192956301
#
#                                               diagnosis  shapley value
# 0                                  CONTUSION OF HAND(S)      -0.298961
# 1                                     Gout, unspecified      -0.024155
# 2      FALL FROM OTHER SLIPPING, TRIPPING, OR STUMBLING       0.218266
# 3               MONONEURITIS OF LOWER LIMB, UNSPECIFIED       0.179479
# 4                       12 weeks gestation of pregnancy      -0.581113
# ...                                                 ...            ...
# 7233      Unilateral primary osteoarthritis, right knee      -0.031707
# ...

# %%
diagnosis_csv = diagnosis_csv.sort_values(by=['shapley value']).drop_duplicates('patient id', keep='last')
diagnosis_csv
# Out:
#       Unnamed: 0  patient id  \
# 6335        6335   196099686
# 4151        4151   143132262
# 2952        2952   136321030
# 6319        6319   325585501
# 1355        1355   180356495
# ...          ...         ...
# 4042        4042   200287564
# 6220        6220   325074162
# 4772        4772   123743529
# 2744        2744   195040610
# 6526        6526   118505503
#
#                                               diagnosis  shapley value
# 6335     Encounter for full-term uncomplicated delivery      -2.311832
# 4151                                 CALCULUS OF KIDNEY      -1.870644
# 2952                       ABNORMAL COAGULATION PROFILE      -1.865110
# 6319  Other placental conditions affecting managemen...      -1.816807
# 1355   Spotting complicating pregnancy, first trimester      -1.687211
# ...                                                 ...            ...
# 4042  Bus occupant injured in collision with heavy t...       3.337101
# ...

# %%
medication_csv = medication_csv.sort_values(by=['shapley value']).drop_duplicates('patient id', keep='last')

# %%
medication_csv
# Out:
#       Unnamed: 0  patient id               medication  shapley value
# 5935        5935   200289649              ondansetron      -3.843623
# 7180        7180   324024714               carboprost      -2.186489
# 6505        6505   123745067              ondansetron      -2.062227
# 7927        7927   181420213            acetaminophen      -1.951740
# 5729        5729   325069705  acetaminophen-oxycodone      -1.882024
# ...          ...         ...                      ...            ...
# 7722        7722   135094222                 fentanyl       3.648192
# 7285        7285   153107136              ondansetron       3.752437
# 3887        3887   174070463            acetaminophen       4.319402
# 3570        3570   174069719             levofloxacin       4.423902
# 4921        4921   153101430             LVP solution       4.532103
#
# [5656 rows x 4 columns]

# %%
demographics_csv = demographics_csv.drop_duplicates('patient id', keep='last')

# %%
demographics_csv
# Out:
#        Unnamed: 0  patient id      gender  age  risk score   risk label
# 0               0   194248707      Female   18     0.96948    High Risk
# 1               1   130940934      Female   47     0.22163     Low Risk
# 2               2   111935499      Female   30     0.96407    High Risk
# 3               3   118620172      Female   65     0.71312  Medium Risk
# 4               4   112459790  Not Mapped   28     0.25254     Low Risk
# ...           ...         ...         ...  ...         ...          ...
# 10290       10290   131090312        Male   22     0.96758    High Risk
# 10291       10291   180358124        Male   50     0.96405    High Risk
# 10292       10292   145405591        Male   31     0.96406    High Risk
# 10293       10293   192956301      Female   24     0.71431  Medium Risk
# 10294       10294   143673230        Male   29     0.96406    High Risk
#
# [10295 rows x 6 columns]

# %%
medication_merged = demographics_csv.merge(medication_csv, on = 'patient id', how = 'inner')

# %%
medication_merged
# Out:
#       Unnamed: 0_x  patient id  gender  age  risk score   risk label  \
# 0                1   130940934  Female   47     0.22163     Low Risk
# 1                5   155058192    Male   34     0.22160     Low Risk
# 2                6   181403665  Female   77     0.61458  Medium Risk
# 3               10   151388186  Female   77     0.71393  Medium Risk
# 4               13   145621024  Female   65     0.96622    High Risk
# ...            ...         ...     ...  ...         ...          ...
# 5650         10288   324028291  Female   40     0.96407    High Risk
# 5651         10289   175130502    Male   54     0.96407    High Risk
# 5652         10290   131090312    Male   22     0.96758    High Risk
# 5653         10293   192956301  Female   24     0.71431  Medium Risk
# 5654         10294   143673230    Male   29     0.96406    High Risk
#
#       Unnamed: 0_y                                 medication  shapley value
# ...

# %%
all_merged = medication_merged.merge(diagnosis_csv, on = 'patient id', how = 'inner')

# %%
all_merged
# Out:
#       Unnamed: 0_x  patient id  gender  age  risk score   risk label  \
# 0                6   181403665  Female   77     0.61458  Medium Risk
# 1               10   151388186  Female   77     0.71393  Medium Risk
# 2               13   145621024  Female   65     0.96622    High Risk
# 3               18   111673388  Female   74     0.22166     Low Risk
# 4               20   196083758  Female   65     0.69638  Medium Risk
# ...            ...         ...     ...  ...         ...          ...
# 2138         10271   198883069  Female   26     0.99352    High Risk
# 2139         10272   147867492  Female   57     0.72671  Medium Risk
# 2140         10279   192956274    Male   30     0.96400    High Risk
# 2141         10282   200296309  Female   35     0.96408    High Risk
# 2142         10293   192956301  Female   24     0.71431  Medium Risk
#
#       Unnamed: 0_y                                 medication  \
# 0                2                LVP solution with potassium
# ...

# %%
all_merged.columns
# Out:
# Index(['Unnamed: 0_x', 'patient id', 'gender', 'age', 'risk score',
#        'risk label', 'Unnamed: 0_y', 'medication', 'shapley value_x',
#        'Unnamed: 0', 'diagnosis', 'shapley value_y'],
#       dtype='object')

# %%
all_merged.drop(['Unnamed: 0_x', 'Unnamed: 0_y', 'shapley value_x',
       'Unnamed: 0', 'shapley value_y'], axis = 1, inplace = True)

# %%
all_merged
# Out:
#       patient id  gender  age  risk score   risk label  \
# 0      181403665  Female   77     0.61458  Medium Risk
# 1      151388186  Female   77     0.71393  Medium Risk
# 2      145621024  Female   65     0.96622    High Risk
# 3      111673388  Female   74     0.22166     Low Risk
# 4      196083758  Female   65     0.69638  Medium Risk
# ...          ...     ...  ...         ...          ...
# 2138   198883069  Female   26     0.99352    High Risk
# 2139   147867492  Female   57     0.72671  Medium Risk
# 2140   192956274    Male   30     0.96400    High Risk
# 2141   200296309  Female   35     0.96408    High Risk
# 2142   192956301  Female   24     0.71431  Medium Risk
#
#                                      medication  \
# 0                   LVP solution with potassium
# 1     tetanus/diphtheria/pertussis, acel (Tdap)
# 2                                   butorphanol
# 3                 sulfamethoxazole-trimethoprim
# 4                                     midazolam
# ...

# %%
len(all_merged)
# Out:
# 2143

# %%
from threading import Event
summaries = []
counter = 0

for i in range(len(all_merged)):
    record = all_merged.loc[i]
    prompt = f'''Age is {record[2]} years, gender is {record[1]}. 
Diagnosed with {record[6]} has been prescribed {record[5]} and is at {record[4]} of opioid disorder. 
How should further medications be prescribed?
    '''
    result = generate_patient_summary(prompt)
    summaries.append(result)

summaries
# Out:
# ['\n\nThe patient should be prescribed opioids with caution, as they are at medium risk of developing an opioid disorder.',
#  '\n\nThe patient should be prescribed a non-opioid pain medication such as acetaminophen or ibuprofen. If the pain is severe, the patient may be prescribed a short-acting opioid such as hydrocodone or oxycodone. The patient should be monitored closely for signs of opioid disorder.',
#  "\n\nThe prescribing physician should consider the patient's age, gender, and diagnosis when prescribing opioids. In this case, the patient is 65 years old, female, and has been diagnosed with unilateral primary osteoarthritis of the left knee. The patient has been prescribed butorphanol for pain relief and is at high risk of developing an opioid disorder. The physician should carefully consider the risks and benefits of prescribing opioids to this patient and should discuss the risks and benefits of opioids with the patient.",
# ...

# %%
len(summaries)
# Out:
# 2143

# %%
all_merged['summary'] = summaries

# %%
for idx, text in enumerate(summaries):
    summaries[idx] = summaries[idx].replace("\n\n", "");

print(summaries)
# Out:
# ['The patient should be prescribed opioids with caution, as they are at medium risk of developing an opioid disorder.', 'The patient should be prescribed a non-opioid pain medication such as acetaminophen or ibuprofen. If the pain is severe, the patient may be prescribed a short-acting opioid such as hydrocodone or oxycodone. The patient should be monitored closely for signs of opioid disorder.', "The prescribing physician should consider the patient's age, gender, and diagnosis when prescribing opioids. In this case, the patient is 65 years old, female, and has been diagnosed with unilateral primary osteoarthritis of the left knee. The patient has been prescribed butorphanol for pain relief and is at high risk of developing an opioid disorder. The physician should carefully consider the risks and benefits of prescribing opioids to this patient and should discuss the risks and benefits of opioids with the patient.", "The prescribing physician should consider the patient's age, gender
# ...

# %%
all_merged['summary'] = summaries

# %%
all_merged
# Out:
#       patient id  gender  age  risk score   risk label  \
# 0      181403665  Female   77     0.61458  Medium Risk
# 1      151388186  Female   77     0.71393  Medium Risk
# 2      145621024  Female   65     0.96622    High Risk
# 3      111673388  Female   74     0.22166     Low Risk
# 4      196083758  Female   65     0.69638  Medium Risk
# ...          ...     ...  ...         ...          ...
# 2138   198883069  Female   26     0.99352    High Risk
# 2139   147867492  Female   57     0.72671  Medium Risk
# 2140   192956274    Male   30     0.96400    High Risk
# 2141   200296309  Female   35     0.96408    High Risk
# 2142   192956301  Female   24     0.71431  Medium Risk
#
#                                      medication  \
# 0                   LVP solution with potassium
# 1     tetanus/diphtheria/pertussis, acel (Tdap)
# 2                                   butorphanol
# 3                 sulfamethoxazole-trimethoprim
# 4                                     midazolam
# ...

# %%
all_merged.to_csv('summary.csv')

# %%
pwd
# Out:
# '/Users/arjun_ob/Documents'

# %%
import pandas as pd
diagnosis_csv = pd.read_csv('/Users/arjun_ob/Documents/daignosis1.csv')

# %%
diagnosis_csv[diagnosis_csv['patient id'] == 326238265]
# Out:
#     patient id         diagnosis  shapley value
# 17   326238265  TIETZE'S DISEASE       0.000807
# 18   326238265      Chronic pain       0.043913

# %%
# diagnosis_csv.loc[
diagnosis_csv['hepatitis'] = diagnosis_csv['diagnosis'].str.contains("hepatitis", case = False)

# %%
diagnosis_csv['chronic pain'] = diagnosis_csv['diagnosis'].str.contains("chronic pain", case = False)

# %%
diagnosis_csv['mental health issues'] = diagnosis_csv['diagnosis'].str.contains("mental", case = False)

# %%
diagnosis_csv['alcohol issues'] = diagnosis_csv['diagnosis'].str.contains("alcohol", case = False)

# %%
diagnosis_csv['patient id']
# Out:
# 0       112459790
# 1       112459790
# 2       181403665
# 3       181403665
# 4       151388186
#           ...
# 7233    180358124
# 7234    192956301
# 7235    192956301
# 7236    192956301
# 7237    192956301
# Name: patient id, Length: 7238, dtype: int64

# %%
diagnosis_csv[diagnosis_csv['patient id'] == 324928722]
# Out:
#      Unnamed: 0  patient id  \
# 282         282   324928722
#
#                                              diagnosis  shapley value  \
# 282  Personal history of other mental and behaviora...       -0.19017
#
#      hepatitis  chronic pain  mental health issues  alcohol issues
# 282      False         False                  True           False

# %%
diagnosis_csv.drop(['mental health', 'alcohol issue', 'chronic pain',
       'hepatitis'], axis = 1, inplace = True)

# %%
a = diagnosis_csv['patient id'].unique()
print(sorted(a))
# Out:
# [105493605, 105513009, 106103017, 106168855, 106299419, 106562328, 106693181, 106824203, 106954909, 107086699, 107214461, 107217090, 107217669, 107217962, 107218471, 107348700, 108472110, 109554412, 109838701, 110232045, 110887212, 111018683, 111019122, 111019598, 111019631, 111281191, 111281622, 111281648, 111673388, 111935713, 111936079, 112328738, 112329526, 112853595, 113247417, 113377539, 114033541, 114034010, 114034069, 114426691, 114600764, 117442216, 117442240, 117462565, 117572478, 117964882, 118359308, 118620452, 118865703, 119407803, 119538600, 119801216, 121766117, 121767602, 121897312, 122029528, 122159378, 122421734, 122815987, 123601035, 123601440, 124125256, 124125910, 124185432, 124256900, 124650779, 125694751, 125960424, 126486038, 126542502, 127009803, 128057841, 128482787, 128887717, 130237295, 130241972, 130810805, 130935657, 130940934, 130942390, 131420072, 131466717, 131989583, 131990774, 132121498, 132252286, 132476317, 132514080, 133432159, 133432476, 1340430
# ...

# %%
diagnosis_csv[diagnosis_csv['patient id'] == 326238265]
# Out:
#     patient id         diagnosis  shapley value
# 17   326238265  TIETZE'S DISEASE       0.000807
# 18   326238265      Chronic pain       0.043913

# %%
m = list(diagnosis_csv['diagnosis'][diagnosis_csv['patient id'] == 326238265].str.contains("sdfgfg", case = False))

# %%
m
# Out:
# [False, False]

# %%
if True in m:
        print("Yes")
else:
        print("No")
# Out:
# No

# %%
hepatitis_history = []
chronic_history = []
alcohol_history = []
mental_history = []

for patient in a:
    hepatitis = list(diagnosis_csv['diagnosis'][diagnosis_csv['patient id'] == patient].str.contains("hepatitis", case = False))
    chronic_pain = list(diagnosis_csv['diagnosis'][diagnosis_csv['patient id'] == patient].str.contains("chronic pain", case = False))
    alcohol_issue = list(diagnosis_csv['diagnosis'][diagnosis_csv['patient id'] == patient].str.contains("alcohol", case = False))
    mental_health_issue = list(diagnosis_csv['diagnosis'][diagnosis_csv['patient id'] == patient].str.contains("mental", case = False))
    
    if True in hepatitis:
        hepatitis_history.append("Yes")
    else:
        hepatitis_history.append("No")
        
    if True in chronic_pain:
        chronic_history.append("Yes")
    else:
        chronic_history.append("No")
        
    if True in alcohol_issue:
        alcohol_history.append("Yes")
    else:
        alcohol_history.append("No")
        
    if True in mental_health_issue:
        mental_history.append("Yes")
    else:
        mental_history.append("No")

# %%
len(hepatitis_history)
# Out:
# 231

# %%
len(chronic_history)
# Out:
# 231

# %%
len(alcohol_history)
# Out:
# 231

# %%
len(mental_history)
# Out:
# 231

# %%
len(a)
# Out:
# 231

# %%
dict = {'patient id': a, 
        'hepatitis history': hepatitis_history, 
        'chronic pain history': chronic_history, 
        'alcohol history': alcohol_history, 
       'mental issues history': mental_history} 
   
df = pd.DataFrame(dict)

# %%
df
# Out:
#      patient id hepatitis history chronic pain history alcohol history  \
# 0     130940934                No                   No              No
# 1     147849230                No                   No              No
# 2     147193879                No                   No              No
# 3     196214808                No                   No              No
# 4     106299419                No                   No              No
# ..          ...               ...                  ...             ...
# 226   324667102                No                   No              No
# 227   118865703                No                   No              No
# 228   197228332                No                   No              No
# 229   108472110                No                   No              No
# 230   131420072                No                   No              No
#
#     mental issues history
# 0                      No
# 1                      No
# 2                      No
# ...

# %%
df[df['patient id'] == 326238265]
# Out:
#     patient id hepatitis history chronic pain history alcohol history  \
# 13   326238265                No                  Yes              No
#
#    mental issues history
# 13                    No

# %%
df.to_csv('history_diagnosis.csv')

# %%
pwd
# Out:
# '/Users/arjun_ob/Documents'

# %%
import pandas as pd
history_diagnosis = pd.read_csv('/Users/arjun_ob/Documents/history_diagnosis.csv')

# %%
history_diagnosis.head()
# Out:
#    Unnamed: 0  patient id hepatitis history chronic pain history  \
# 0           0   130940934                No                   No
# 1           1   147849230                No                   No
# 2           2   147193879                No                   No
# 3           3   196214808                No                   No
# 4           4   106299419                No                   No
#
#   alcohol history mental issues history
# 0              No                    No
# 1              No                    No
# 2              No                    No
# 3              No                    No
# 4              No                    No

# %%
history_diagnosis.loc[0]['hepatitis history']
# Out:
# 'No'

# %%
history_lst = []
for i in range(len(history_diagnosis)):
    string = "The patient "
    for j in ['hepatitis history', 'chronic pain history', 'alcohol history', 'mental issues history']:
        if history_diagnosis.loc[i][j] == "Yes":
            string = string + "has " + j + " "
        else:
            string = string + "does not have " + j + " "
    string = string + "."
    history_lst.append(string)
    string = ""


history_lst
# Out:
# ['The patient does not have hepatitis history does not have chronic pain history does not have alcohol history does not have mental issues history .',
#  'The patient does not have hepatitis history does not have chronic pain history does not have alcohol history does not have mental issues history .',
#  'The patient does not have hepatitis history does not have chronic pain history does not have alcohol history does not have mental issues history .',
#  'The patient does not have hepatitis history does not have chronic pain history does not have alcohol history does not have mental issues history .',
#  'The patient does not have hepatitis history does not have chronic pain history does not have alcohol history does not have mental issues history .',
#  'The patient does not have hepatitis history has chronic pain history does not have alcohol history does not have mental issues history .',
# ...

# %%
history_diagnosis['history'] = history_lst

# %%
len(history_lst)
# Out:
# 231

# %%
history_diagnosis
# Out:
#      Unnamed: 0  patient id hepatitis history chronic pain history  \
# 0             0   130940934                No                   No
# 1             1   147849230                No                   No
# 2             2   147193879                No                   No
# 3             3   196214808                No                   No
# 4             4   106299419                No                   No
# ..          ...         ...               ...                  ...
# 226         226   324667102                No                   No
# 227         227   118865703                No                   No
# 228         228   197228332                No                   No
# 229         229   108472110                No                   No
# 230         230   131420072                No                   No
#
#     alcohol history mental issues history  \
# 0                No                    No
# 1                No                    No
# ...

# %%
history_diagnosis.to_csv('history_diagnosis.csv')

# %%
history_diagnosis.loc[0]['history']
# Out:
# 'The patient does not have hepatitis history does not have chronic pain history does not have alcohol history does not have mental issues history .'

# %%
history_diagnosis.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
history_diagnosis.to_csv('history_diagnosis.csv')
